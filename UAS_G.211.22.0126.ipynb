# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membaca file CSV
df = pd.read_csv('stock.csv', sep=';')

# Menampilkan histogram untuk atribut "Purchase Price" menggunakan matplotlib
plt.figure(figsize=(20, 6))
plt.hist(df['Purchase Price'], bins=50, edgecolor='black')
plt.xlabel('Purchase Price')
plt.ylabel('Count')
plt.title('Histogram of Purchase Price')
plt.show()

# Menampilkan histogram untuk atribut "Current Price" menggunakan Seaborn
plt.figure(figsize=(8, 6))
plt.hist(df['Current Price'], bins=50, edgecolor='black')
plt.xlabel('Current Price')
plt.ylabel('Count')
plt.title('Histogram of Current Price')
plt.show()

# Menampilkan bar chart untuk atribut "Purchase Price" menggunakan Seaborn
plt.figure(figsize=(20, 4))
plt.hist(df['Purchase Price'], bins=50, edgecolor='black')
plt.xlabel('Purchase Price')
plt.ylabel('Count')
plt.title('Bar Chart of Purchase Price')
plt.show()

# %%
df = pd.read_csv('stock.csv', sep=';')
df.head(12)
# Out:
#                     Stock Name Symbol  Shares Purchase Price  Cost Basis  \
# 0                        Apple   AAPL     100         $90.00   $9,000.00
# 1                    Microsoft   MSFT     200         $32.00   $6,400.00
# 2                   Salesforce    CRM     150         $25.00   $3,750.00
# 3                       Oracle   ORCL     250         $50.00  $12,500.00
# 4   Hewlett Packard Enterprise    HPE     500         $18.00   $9,000.00
# 5                     Alphabet   GOOG     100        $225.00  $22,500.00
# 6                        Intel   INTO     200         $22.00   $4,400.00
# 7                        Cisco   CSCO     225         $18.00   $4,050.00
# 8                     Qualcomm   QCOM     185         $65.00  $12,025.00
# 9                       Amazon   AMZN      50        $800.00  $40,000.00
# 10                      Redhat    RHT     100         $95.00   $9,500.00
# 11                    Facebook     FB    1000         $17.00  $17,000.00
#
# ...

# %%
import pandas as pd

# Membaca file CSV
data = pd.read_csv('stock.csv', sep=';')

# Mengurutkan data berdasarkan kolom 'Dividend/Share' secara menurun
sorted_data = data.sort_values('Dividend/Share', ascending=False)

# Mengambil 5 data teratas
top_5_data = sorted_data.head(5)

# Menampilkan kolom 'Name' dan 'Symbol'
result = top_5_data[['Stock Name', 'Symbol']]

# Menampilkan hasil
print(result)
# Out:
#   Stock Name Symbol
# 0      Apple   AAPL
# 8   Qualcomm   QCOM
# 1  Microsoft   MSFT
# 7      Cisco   CSCO
# 6      Intel   INTO

# %%
import pandas as pd

# Membaca file CSV
data = pd.read_csv('stock.csv', sep=';')

# Mengurutkan data berdasarkan kolom 'Dividend/Share' secara menurun
sorted_data = data.sort_values('Market Value', ascending=False)

# Mengambil 5 data teratas
top_5_data = sorted_data.head(5)

# Menampilkan kolom 'Name' dan 'Symbol'
result = top_5_data[['Stock Name', 'Symbol']]

# Menampilkan hasil
print(result)
# Out:
#                     Stock Name Symbol
# 5                     Alphabet   GOOG
# 4   Hewlett Packard Enterprise    HPE
# 10                      Redhat    RHT
# 7                        Cisco   CSCO
# 12                     Twitter   TWTR

# %%
import pandas as pd

# Membaca file CSV
data = pd.read_csv('stock.csv', sep=';')

# Mengurutkan data berdasarkan kolom 'Dividend/Share' secara menurun
sorted_data = data.sort_values('Annual Yield', ascending=False)

# Mengambil 5 data teratas
top_5_data = sorted_data.head(7)

# Menampilkan kolom 'Name' dan 'Symbol'
result = top_5_data[['Stock Name', 'Symbol']]

# Menampilkan hasil
print(result)
# Out:
#                    Stock Name Symbol
# 8                    Qualcomm   QCOM
# 7                       Cisco   CSCO
# 6                       Intel   INTO
# 1                   Microsoft   MSFT
# 0                       Apple   AAPL
# 4  Hewlett Packard Enterprise    HPE
# 3                      Oracle   ORCL
